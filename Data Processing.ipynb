# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r"C:\Users\TheDarkAce\Jupyter scripts\Datathon Chevron\filesForStartOfDatathon/training.csv")

# %%
df.head()
# Out:
#                segment_id wellbore_chev_no_id area_id  formation_id  \
# 0  wellbore_chev_no_0_727  wellbore_chev_no_0  area_0  formation_62
# 1  wellbore_chev_no_0_728  wellbore_chev_no_0  area_0  formation_61
# 2  wellbore_chev_no_0_729  wellbore_chev_no_0  area_0  formation_59
# 3  wellbore_chev_no_0_730  wellbore_chev_no_0  area_0  formation_65
# 4  wellbore_chev_no_0_731  wellbore_chev_no_0  area_0  formation_65
#
#   bit_model_id  drillbit_size  min_depth  max_depth  rate_of_penetration  \
# 0  bit_model_1          12.25    21834.5    21839.5            99.614650
# 1  bit_model_1          12.25    21840.0    21869.5            99.354021
# 2  bit_model_1          12.25    21870.0    21899.5            83.622907
# 3  bit_model_1          12.25    21900.0    21929.5            85.427731
# 4  bit_model_1          12.25    21930.0    21959.5           100.639811
#
#    surface_weight_on_bit  surface_rpm
# 0              43.533280   150.369091
# 1              42.382033   150.369001
# ...

# %%
df.shape
# Out:
# (6838, 11)

# %%
df["segment_id"].unique()
# Out:
# array(['wellbore_chev_no_0_727', 'wellbore_chev_no_0_728',
#        'wellbore_chev_no_0_729', ..., 'wellbore_chev_no_9_829',
#        'wellbore_chev_no_9_830', 'wellbore_chev_no_9_831'], dtype=object)

# %%
for i in df.columns:
    print(i)
    print(df[i].isnull().sum())
# Out:
# segment_id
# 0
# wellbore_chev_no_id
# 0
# area_id
# 0
# formation_id
# 0
# bit_model_id
# 0
# drillbit_size
# 0
# min_depth
# 0
# max_depth
# 0
# rate_of_penetration
# 0
# surface_weight_on_bit
# 0
# surface_rpm
# 0

# %%
for i in df.columns:
    print(i)
    print(df[i].unique().shape)
# Out:
# segment_id
# (6838,)
# wellbore_chev_no_id
# (21,)
# area_id
# (2,)
# formation_id
# (239,)
# bit_model_id
# (38,)
# drillbit_size
# (7,)
# min_depth
# (990,)
# max_depth
# (1542,)
# rate_of_penetration
# (6838,)
# surface_weight_on_bit
# (6837,)
# surface_rpm
# (6210,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
float_cols = []
for i in df.columns:
    if df[i].dtype == "float64" and i != "rate_of_penetration":
        float_cols.append(i)
print(float_cols)
df_float = df[float_cols]
sc = scaler.fit(df_float)
df_float = sc.transform(df_float)
df_float = pd.DataFrame(df_float)
df_float.columns = float_cols
df_cat = df.drop(float_cols,axis = 1)
df_final = pd.concat([df_cat,df_float],axis = 1)
# Out:
# ['drillbit_size', 'min_depth', 'max_depth', 'surface_weight_on_bit', 'surface_rpm']

# %%
df = df_final

# %%
encoders = {}
encoder = LabelEncoder()
for i in df.columns:
    if i != "segment_id":
        if df[i].dtype == "object":
            enc = LabelEncoder()
            enc = enc.fit(df[i])
            df[i] = enc.transform(df[i])
        
#df_temp = pd.DataFrame(df_temp)
#df_temp.cols = df_temp_cols

# %%
df.head()
# Out:
#                segment_id  wellbore_chev_no_id  area_id  formation_id  \
# 0  wellbore_chev_no_0_727                    0        0           200
# 1  wellbore_chev_no_0_728                    0        0           199
# 2  wellbore_chev_no_0_729                    0        0           196
# 3  wellbore_chev_no_0_730                    0        0           203
# 4  wellbore_chev_no_0_731                    0        0           203
#
#    bit_model_id  rate_of_penetration  drillbit_size  min_depth  max_depth  \
# 0             1            99.614650      -0.987049   0.387782   0.383551
# 1             1            99.354021      -0.987049   0.388740   0.388778
# 2             1            83.622907      -0.987049   0.393968   0.394006
# 3             1            85.427731      -0.987049   0.399196   0.399234
# 4             1           100.639811      -0.987049   0.404423   0.404462
#
#    surface_weight_on_bit  surface_rpm
# 0               0.579398    -0.233714
# ...

# %%
#df.to_csv(r"C:\Users\TheDarkAce\Jupyter scripts\Datathon Chevron\filesForStartOfDatathon/preprocessed.csv",index = False)

# %%
pd.read_csv(r"C:\Users\TheDarkAce\Jupyter scripts\Datathon Chevron\filesForStartOfDatathon/preprocessed.csv")
# Out:
#                   segment_id  wellbore_chev_no_id  area_id  formation_id  \
# 0     wellbore_chev_no_0_727                    0        0           200
# 1     wellbore_chev_no_0_728                    0        0           199
# 2     wellbore_chev_no_0_729                    0        0           196
# 3     wellbore_chev_no_0_730                    0        0           203
# 4     wellbore_chev_no_0_731                    0        0           203
# ...                      ...                  ...      ...           ...
# 6833  wellbore_chev_no_9_827                   20        0           226
# 6834  wellbore_chev_no_9_828                   20        0           225
# 6835  wellbore_chev_no_9_829                   20        0           225
# 6836  wellbore_chev_no_9_830                   20        0           225
# 6837  wellbore_chev_no_9_831                   20        0           225
#
#       bit_model_id  rate_of_penetration  drillbit_size  min_depth  max_depth  \
# ...
