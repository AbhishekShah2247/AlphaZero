# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\TheDarkAce\Jupyter scripts\Datathon Chevron\filesForStartOfDatathon/training.csv")
processed = pd.read_csv(r"C:\Users\TheDarkAce\Jupyter scripts\Datathon Chevron\filesForStartOfDatathon/preprocessed.csv")

# %%
df.shape
# Out:
# (6838, 11)

# %%
df.head()
# Out:
#                segment_id wellbore_chev_no_id area_id  formation_id  \
# 0  wellbore_chev_no_0_727  wellbore_chev_no_0  area_0  formation_62
# 1  wellbore_chev_no_0_728  wellbore_chev_no_0  area_0  formation_61
# 2  wellbore_chev_no_0_729  wellbore_chev_no_0  area_0  formation_59
# 3  wellbore_chev_no_0_730  wellbore_chev_no_0  area_0  formation_65
# 4  wellbore_chev_no_0_731  wellbore_chev_no_0  area_0  formation_65
#
#   bit_model_id  drillbit_size  min_depth  max_depth  rate_of_penetration  \
# 0  bit_model_1          12.25    21834.5    21839.5            99.614650
# 1  bit_model_1          12.25    21840.0    21869.5            99.354021
# 2  bit_model_1          12.25    21870.0    21899.5            83.622907
# 3  bit_model_1          12.25    21900.0    21929.5            85.427731
# 4  bit_model_1          12.25    21930.0    21959.5           100.639811
#
#    surface_weight_on_bit  surface_rpm
# 0              43.533280   150.369091
# 1              42.382033   150.369001
# ...

# %%
cat_cols = ["segment_id","rate_of_penetration","wellbore_chev_no_id","area_id","formation_id","bit_model_id"]
for i in df.columns:
    if i not in cat_cols:
        print(i)
        print(df["rate_of_penetration"].corr(df[i]))
# Out:
# drillbit_size
# 0.3092216884469472
# min_depth
# -0.4023057701656263
# max_depth
# -0.40229036523257244
# surface_weight_on_bit
# 0.5086175362695767
# surface_rpm
# 0.6117025941443732

# %%
wellbore = df.groupby("wellbore_chev_no_id")

# %%
for k,v in wellbore:
    print(k)
    for i in v.columns:
        if i not in cat_cols:
            print(i)
            print(v["rate_of_penetration"].corr(v[i]))
    print()
    print()
# Out:
# wellbore_chev_no_0
# drillbit_size
# nan
# min_depth
# -0.886010232298669
# max_depth
# -0.886180170669688
# surface_weight_on_bit
# 0.44310268060745767
# surface_rpm
# -0.2481175586905098
#
#
# wellbore_chev_no_1
# drillbit_size
# 0.09945801984036874
# min_depth
# -0.44333328292664087
# max_depth
# -0.44216434226536644
# surface_weight_on_bit
# 0.0431243624422387
# surface_rpm
# 0.6690125654425791
#
#
# wellbore_chev_no_10
# drillbit_size
# nan
# min_depth
# 0.06795460637714174
# max_depth
# 0.06692188260612268
# surface_weight_on_bit
# 0.33434430188279307
# surface_rpm
# 0.3877139686508097
#
#
# wellbore_chev_no_11
# drillbit_size
# nan
# min_depth
# -0.7382770398569507
# max_depth
# -0.7380531552516787
# surface_weight_on_bit
# 0.2072882156868787
# surface_rpm
# 0.0877349479102231
#
#
# wellbore_chev_no_12
# drillbit_size
# nan
# min_depth
# -0.6068029260570857
# max_depth
# -0.6074231486803486
# surface_weight_on_bit
# -0.18981505501856175
# surface_rpm
# -0.016638073968381597
#
# ...

# %%
df.describe()
# Out:
#        drillbit_size     min_depth     max_depth  rate_of_penetration  \
# count    6838.000000   6838.000000   6838.000000          6838.000000
# mean       15.726309  19609.123574  19638.444245           106.997573
# std         3.522179   5739.149255   5739.051073            55.061943
# min         8.500000   4988.500000   5009.500000             5.382589
# 25%        12.250000  14970.000000  14999.500000            62.480077
# 50%        16.500000  20040.000000  20069.500000           100.828372
# 75%        18.125000  24120.000000  24149.500000           136.087159
# max        26.000000  31050.000000  31070.750000           512.754999
#
#        surface_weight_on_bit  surface_rpm
# count            6838.000000  6838.000000
# mean               35.791311   156.262449
# std                13.363067    25.217998
# min                 5.203333    60.594999
# 25%                26.348941   140.665599
# 50%                36.983090   159.661078
# ...

# %%
num_cols = ["drillbit_size","min_depth","max_depth","rate_of_penetration","surface_weight_on_bit","surface_rpm"]
for i in num_cols:
    plt.figure(figsize = (6, 6))
    sns.kdeplot(df[i])
    plt.title(f'%s Distribution {i}')

# %%
df.nunique()
# Out:
# segment_id               6838
# wellbore_chev_no_id        21
# area_id                     2
# formation_id              239
# bit_model_id               38
# drillbit_size               7
# min_depth                 990
# max_depth                1542
# rate_of_penetration      6838
# surface_weight_on_bit    6837
# surface_rpm              6210
# dtype: int64

# %%
df.head()
# Out:
#                segment_id wellbore_chev_no_id area_id  formation_id  \
# 0  wellbore_chev_no_0_727  wellbore_chev_no_0  area_0  formation_62
# 1  wellbore_chev_no_0_728  wellbore_chev_no_0  area_0  formation_61
# 2  wellbore_chev_no_0_729  wellbore_chev_no_0  area_0  formation_59
# 3  wellbore_chev_no_0_730  wellbore_chev_no_0  area_0  formation_65
# 4  wellbore_chev_no_0_731  wellbore_chev_no_0  area_0  formation_65
#
#   bit_model_id  drillbit_size  min_depth  max_depth  rate_of_penetration  \
# 0  bit_model_1          12.25    21834.5    21839.5            99.614650
# 1  bit_model_1          12.25    21840.0    21869.5            99.354021
# 2  bit_model_1          12.25    21870.0    21899.5            83.622907
# 3  bit_model_1          12.25    21900.0    21929.5            85.427731
# 4  bit_model_1          12.25    21930.0    21959.5           100.639811
#
#    surface_weight_on_bit  surface_rpm
# 0              43.533280   150.369091
# 1              42.382033   150.369001
# ...

# %%
temp = df[df["rate_of_penetration"] < 270]
print(temp.shape)
# Out:
# (6778, 11)

# %%
# Brute force FE
